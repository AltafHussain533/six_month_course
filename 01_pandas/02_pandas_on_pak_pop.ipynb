# %% [markdown]
# # **Pakistani Population Analysis**

# %% [markdown]
# The Data was collected from the following [link](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset):
#
# **Years of Data:**
# 1. 2017
# 2. 1998

# %% [markdown]
# ## *The Dataset colelcted from the source has follwoing description:*
# `Description`
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# `Features`
# Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# District: Districts within each division, representing larger administrative units.
#
# Sub-Division: Sub-divisions or tehsils within each district, providing more localized data.
#
# Area: The land area (in square kilometers) of each sub-division.
#
# Urban Population 2017: The population of urban areas within each sub-division for the year 2017.
#
# Rural Population 2017: The population of rural areas within each sub-division for the year 2017.
#
# Male Population 2017: The male population within each sub-division for the year 2017.
#
# Female Population 2017: The female population within each sub-division for the year 2017.
#
# Transgender Population 2017: The population of transgender individuals within each sub-division for the year 2017.
#
# Sex Ratio 2017: The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# Population in 1998: The total population of each sub-division as recorded in the 1998 census.
#
# Annual Growth Rate: The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# Data Source
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# `Data Usage`
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of this analysis:
#
# We will fill this at the end or during the process

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Improt the dataset
df = pd.read_csv('./data/data.csv')

# %% [markdown]
# # 1. Composition

# %%
df.head(3)
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# 0                   42             104.70  ...                   407768
# 1                   54             102.73  ...                   395983
# 2                   44             102.30  ...                   250959
#
#    ANNUAL GROWTH RATE (RURAL)  ALL SEXES (URBAN)  MALE (URBAN)  \
# ...

# %%
# Explore the data (Compsotion)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    str
#  1   DIVISION                    528 non-null    str
#  2   DISTRICT                    528 non-null    str
#  3   SUB DIVISION                528 non-null    str
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %% [markdown]
# # 1. Category
#  **Definition:**  A data type used for variables that can only take on a limited, fixed number of possible values\
#  **Key Behavior:** It maps repeating text values to internal integers, significantly speeding up processing times\
#  **Examples:**  ["High", "Medium", "Low"] or ["Male", "Female"].
# # 2. Int (Integer)
# **Definition:** A data type that represents whole numbers without any fractional or decimal components.\
# **Key Behavior:** It supports precise, fast mathematical calculations and can be positive, negative, or zero\
# **Examples:** 42, -7, 0.
# # 3. Float (Floating-Point Number)
# **Definition:** A data type used to represent numbers that contain fractional parts or decimal points.\
# **Key Behavior:**  It is used for measurements and continuous scales but can occasionally introduce tiny rounding errors in complex math.\
# **Examples:** 3.14, -0.005, 2.0.
# # 4. String
# **Definition:**  A data type used to represent a sequence of characters, typically used for plain text.\
# **Key Behavior:**  It treats characters literally, meaning the number "123" stored as a string cannot be used for math until converted.\
# **Examples:** "Hello World", "customer_123", "2026-05-21"

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# max column priniting option 
pd.set_option('display.max_columns', None)  # removes the limit on the number of columns shown.
pd.set_option('display.max_rows', None)     # removes the limit on the number of rows shown.

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# let's see all the columns in the dataset
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='str')

# %%
# let's have a look on dtypes
df.dtypes # we already have seen this in info column as well
# Out:
# PROVINCE                          str
# DIVISION                          str
# DISTRICT                          str
# SUB DIVISION                      str
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
# summary Statistics
df.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
# how many are the missing value
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
missing_value_count = df.isnull().sum()
print(missing_value_count)
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# histogram 
sns.histplot(df, x='AREA (sq.km)')
# Out:
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
# box plot
sns.boxplot(df, x='AREA (sq.km)')
# Out:
# <Axes: xlabel='AREA (sq.km)'>

# %%
# box plot
sns.boxplot(df, y='AREA (sq.km)')
# Out:
# <Axes: ylabel='AREA (sq.km)'>

# %%
sns.boxplot(df, y='ALL SEXES (RURAL)', x='DIVISION')
# Out:
# <Axes: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
sns.boxplot(df, y='ALL SEXES (RURAL)', x='PROVINCE')
# Out:
# <Axes: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %% [markdown]
# # Now in 21/05/2026
# Pakistan is administratively divided into 37 divisions. This includes 31 divisions across the four provinces and 6 divisions within the Pakistan-administered regions.The breakdown by province and territory is as follows:**Punjab:** 10 divisions **Balochistan:** 8 divisions **Khyber Pakhtunkhwa (KPK):** 7 divisions
# **Sindh:** 6 divisions **Azad Jammu and Kashmir (AJK):** 3 divisions **Gilgit-Baltistan:** 3 divisions

# %%
# it is very hard to plot, therefore, we will use groupby function to make tabulated data output
df['DIVISION'].nunique()
# Out:
# 28

# %%
len(df)
# Out:
# 528

# %%
df['DISTRICT'].nunique()
# Out:
# 131

# %% [markdown]
# # Now in 21/05/2026
# There are 170 districts in Pakistan. This total includes all districts within the four provinces, the federal capital territory, and the Pakistan-administered territories.\
# **Punjab:** 42 districts **Khyber Pakhtunkhwa (KPK):** 38 districts **Balochistan:** 36 districts
#  **Sindh:** 30 districts **Gilgit-Baltistan:** 14 districts **Azad Jammu and Kashmir (AJK):** 10 districts **Federal Capital:** 1 district (Islamabad)

# %%
df.groupby(['DIVISION']).size().sort_values()
# counts the total number of rows for each unique administrative division 
# and displays them sorted from smallest to largest size
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# HAZARA DIVISION                 15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# BAHAWALPUR DIVISION             15
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Kalat Division                  18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Sukkur Division                 18
# Zhob Division                   19
# Naseerabad Division             19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Hyderabad Division              30
# Karachi Division                30
# MALAKAND DIVISION               33
# ...

# %%
df.groupby(['DIVISION']).size().sort_values(ascending=False)
# counts the total number of rows for each unique administrative division
# and displays them sorted from largest to smallest size
# Out:
# DIVISION
# Quetta Division                 38
# Makran Division                 37
# MALAKAND DIVISION               33
# Hyderabad Division              30
# Karachi Division                30
# RAWALPINDI DIVISION             22
# Larkana Division                21
# GUJRANWALA DIVISION             20
# Zhob Division                   19
# Naseerabad Division             19
# Mirpurkhas Division             18
# Kalat Division                  18
# Sukkur Division                 18
# PESHAWAR DIVISION               18
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# BAHAWALPUR DIVISION             15
# DERA ISMAIL KHAN DIVISION       15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# HAZARA DIVISION                 15
# D.G.KHAN DIVISION               14
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# MARDAN DIVISION                  7
# ...

# %%
df.groupby(['DIVISION']).size().sort_values().reset_index(name='TOTAL_COUNT')
# counts the total number of rows for each unique administrative division
# and displays them sorted from smallest to largest size
# Out:
#                         DIVISION  TOTAL_COUNT
# 0                 Badin Division            5
# 1                MARDAN DIVISION            7
# 2               SAHIWAL DIVISION            7
# 3                 KOHAT DIVISION           14
# 4                MULTAN DIVISION           14
# 5              D.G.KHAN DIVISION           14
# 6      DERA ISMAIL KHAN DIVISION           15
# 7                HAZARA DIVISION           15
# 8                 BANNU DIVISION           15
# 9   Shaheed Benazirabad Division           15
# 10           BAHAWALPUR DIVISION           15
# 11               LAHORE DIVISION           17
# 12             SARGODHA DIVISION           17
# 13           FAISALABAD DIVISION           17
# 14                Kalat Division           18
# 15             PESHAWAR DIVISION           18
# 16           Mirpurkhas Division           18
# 17               Sukkur Division           18
# 18                 Zhob Division           19
# ...

# %%
df.groupby(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION'])['POPULATION 1998 (RURAL)'].mean()
# calculates the average rural population from the year 1998 for every unique sub-division,
#  nested hierarchically inside its district, division, and province.
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   3979.0
#                                                                          JOHAN SUB-TEHSIL                 12299.0
#                                                                          KALAT TEHSIL                     63919.0
#                                                                          MANGOCHAR TEHSIL                 41590.0
#                                                                          SURAB TEHSIL                     82253.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                28561.0
#                                                                          KARAKH SUB-TEHSIL                21984.0
# ...

# %%
df.groupby(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION'])['POPULATION 1998 (RURAL)'].sum()
# calculates the total rural population from the year 1998 for every unique sub-division,
#  nested hierarchically inside its district, division, and province.
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   3979
#                                                                          JOHAN SUB-TEHSIL                 12299
#                                                                          KALAT TEHSIL                     63919
#                                                                          MANGOCHAR TEHSIL                 41590
#                                                                          SURAB TEHSIL                     82253
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                28561
#                                                                          KARAKH SUB-TEHSIL                21984
#                                                                          KHUZDAR TEHSIL                   70788
# ...

# %%
df.groupby(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION'])['POPULATION 1998 (RURAL)'].agg(['mean', 'sum', 'count'])
# calculates the average, total, and count of rural population from the year 1998 for every unique sub-division,
#  nested hierarchically inside its district, division, and province.
# Out:
#                                                                                                         mean  \
# PROVINCE    DIVISION                     DISTRICT                     SUB DIVISION
# BALOCHISTAN Kalat Division               KALAT DISTRICT               GAZG SUB-TEHSIL                 3979.0
#                                                                       JOHAN SUB-TEHSIL               12299.0
#                                                                       KALAT TEHSIL                   63919.0
#                                                                       MANGOCHAR TEHSIL               41590.0
#                                                                       SURAB TEHSIL                   82253.0
#                                          KHUZDAR DISTRICT             ARANJI SUB-TEHSIL              28561.0
#                                                                       KARAKH SUB-TEHSIL              21984.0
# ...

# %%
df.groupby(['PROVINCE', 'DIVISION'])['POPULATION 1998 (RURAL)'].mean()
# Out:
# PROVINCE     DIVISION
# BALOCHISTAN  Kalat Division                   34953.666667
#              Makran Division                  30517.081081
#              Naseerabad Division              45926.000000
#              Quetta Division                  39651.921053
#              Zhob Division                    43845.157895
# KPK          BANNU DIVISION                  267784.500000
#              DERA ISMAIL KHAN DIVISION       154943.833333
#              HAZARA DIVISION                 213571.066667
#              KOHAT DIVISION                  151992.285714
#              MALAKAND DIVISION               167573.346154
#              MARDAN DIVISION                 287508.857143
#              PESHAWAR DIVISION               374429.000000
# KPK/FATA     BANNU DIVISION                   34714.636364
#              DERA ISMAIL KHAN DIVISION        52092.333333
#              KOHAT DIVISION                   79378.000000
#              MALAKAND DIVISION                85032.428571
# ...

# %%
df.describe().T #2017 and 1998
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %% [markdown]
# # ASSIGNMENT: Calculate the percent change of Population?

# %% [markdown]
# # RURAL POPULATION

# %%
df['ALL SEXES (RURAL)'].sum() # the Rural population of Pakistan in 2017 was
# Out:
# np.int64(130034790)

# %%
print("The Total Rural Population of Pakistan in 2017 was: ",df['ALL SEXES (RURAL)'].sum())
# Out:
# The Total Rural Population of Pakistan in 2017 was:  130034790

# %%
print("The Total Rural Population of Pakistan in 1998 was: ",df['POPULATION 1998 (RURAL)'].sum())
# Out:
# The Total Rural Population of Pakistan in 1998 was:  88401981

# %%
130034790- 88401981
# Out:
# 41632809

# %%
41632809/88401981*100
# Out:
# 47.094882409931515

# %%
# How much Rural Population increased from 1998 - 2017?
pop_rural_1998 = df['POPULATION 1998 (RURAL)'].sum()
pop_rural_2017 = df['ALL SEXES (RURAL)'].sum()
pop_change_rural =  pop_rural_2017 - pop_rural_1998
pop_change_rural
print("The total Rural Population of Pakistan have been increased by 2017 as compared to 1998, and is as follows:",pop_change_rural)
# Out:
# The total Rural Population of Pakistan have been increased by 2017 as compared to 1998, and is as follows: 41632809

# %% [markdown]
# # URBAN POPULATION

# %%
pop_urban_1998 = df['POPULATION 1998 (URBAN)'].sum()
pop_urban_1998
# Out:
# np.int64(42316331)

# %%
pop_urban_2017 = df['ALL SEXES (URBAN)'].sum()
pop_urban_2017
# Out:
# np.int64(74375943)

# %%
# abov assignment To calculate the percentage change of population, we can use the following formula:
# Calculate National Level Rural Aggregates
total_rural_1998 = df['POPULATION 1998 (RURAL)'].sum()
total_rural_2017 = df['ALL SEXES (RURAL)'].sum()
percent_change = ((total_rural_2017 - total_rural_1998) / total_rural_1998)*100
print("The Rural Population of Pakistan increase by:", percent_change,"%, in 2017 from 1998.") #check if this is correct
# Out:
# The Rural Population of Pakistan increase by: 47.094882409931515 %, in 2017 from 1998.

# %%
74375943-42316331
# Out:
# 32059612

# %%
32059612/42316331*100
# Out:
# 75.76179513294761

# %%
# How much Rural Population increased from 1998 - 2017?
pop_urban_1998 = df['POPULATION 1998 (URBAN)'].sum()
pop_urban_2017 = df['ALL SEXES (URBAN)'].sum()
pop_change_urban =  pop_urban_2017 - pop_urban_1998
pop_change_urban
print("The total Urban Population of Pakistan have been increased by 2017 as compared to 1998, and is as follows:",pop_change_urban )
# Out:
# The total Urban Population of Pakistan have been increased by 2017 as compared to 1998, and is as follows: 32059612

# %%
# Population Change
percent_change = (pop_change_urban/pop_urban_1998)*100
print("The Urban Population of Pakistan increase by:", percent_change,"%, in 2017 from 1998.")
# Out:
# The Urban Population of Pakistan increase by: 75.76179513294761 %, in 2017 from 1998.

# %% [markdown]
# # **Assignment:** How to combine 3 columns in one column? make a separate data of everything based on Sex (Male, Female and Transgender?)
