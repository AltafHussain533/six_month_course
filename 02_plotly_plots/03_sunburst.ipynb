# %% [markdown]
# # Sunburst Plot to show Heirarchy

# %%
# create sunburst plot on titanic dataset
import plotly.express as px
import seaborn as sns
# Load Titanic dataset
df = sns.load_dataset('titanic')
# Create a sunburst plot
fig = px.sunburst(df, 
                  path=['sex','class', 'who', 'alive', 'alone'], 
                  values='survived' , color='sex')
# Show the plot
fig.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import plotly.express as px
import seaborn as sns
fig = px.sunburst(tips, 
                  path=['sex','smoker', 'day', 'time'], 
                  values='tip' , color='sex',
                  hover_data=['tip', 'day', 'time'])
# how can we add more values when we hover the pointer on the plot?
# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import plotly.express as px
#       2 import seaborn as sns
# ----> 3 fig = px.sunburst(tips,
#       4                   path=['sex','smoker', 'day', 'time'],
#       5                   values='tip' , color='sex',
#       6                   hover_data=['tip', 'day', 'time'])
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\plotly\express\_chart_types.py:1781, in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, subtitle, template, width, height, branchvalues, maxdepth)
#    1779 if path is not None and branchvalues is None:
#    1780     branchvalues = "total"
# -> 1781 return make_figure(
#    1782     args=locals(),
#    1783     constructor=go.Sunburst,
#    1784     trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
#    1785     layout_patch=layout_patch,
#    1786 )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\plotly\express\_core.py:2514, in make_figure(args, constructor, trace_patch, layout_patch)
#    2512 args = build_dataframe(args, constructor)
#    2513 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 2514     args = process_dataframe_hierarchy(args)
#    2515 if constructor in [go.Pie]:
#    2516     args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\plotly\express\_core.py:2072, in process_dataframe_hierarchy(args)
#    2057     return dframe.with_columns(
#    2058         *[nw.col(col) / nw.col(count_colname) for col in continuous_aggs],
#    2059         *[
#    (...)   2067         ],
#    2068     ).drop([f"{col}{n_unique_token}" for col in discrete_aggs])
#    2070 for i, level in enumerate(path):
#    2071     dfg = (
# -> 2072         df.group_by(path[i:], drop_null_keys=True)
#    2073         .agg(**agg_f)
#    2074         .pipe(post_agg, continuous_aggs, discrete_aggs)
#    2075     )
#    2077     # Path label massaging
#    2078     df_tree = dfg.with_columns(
#    2079         *cols,
#    2080         labels=nw.col(level).cast(nw.String()),
#    2081         parent=nw.lit(""),
#    2082         id=nw.col(level).cast(nw.String()),
#    2083     )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\narwhals\group_by.py:170, in LazyGroupBy.agg(self, *aggs, **named_aggs)
#     163     msg = (
#     164         "Found expression which does not aggregate.\n\n"
#     165         "All expressions passed to GroupBy.agg must aggregate.\n"
#     166         "For example, `df.group_by('a').agg(nw.col('b').sum())` is valid,\n"
#     167         "but `df.group_by('a').agg(nw.col('b'))` is not."
#     168     )
#     169     raise InvalidOperationError(msg)
# --> 170 return self._df._with_compliant(self._grouped.agg(*compliant_aggs))
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\narwhals\_pandas_like\group_by.py:295, in PandasLikeGroupBy.agg(self, *exprs)
#     293 if agg_exprs:
#     294     ns = self.compliant.__narwhals_namespace__()
# --> 295     result = ns._concat_horizontal(self._getitem_aggs(agg_exprs))
#     296 else:
#     297     result = self.compliant.__native_namespace__().DataFrame(
#     298         list(grouped.groups), columns=self._keys
#     299     )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\narwhals\_pandas_like\group_by.py:326, in PandasLikeGroupBy._getitem_aggs(self, exprs)
#     323 def _getitem_aggs(
#     324     self, exprs: Iterable[AggExpr], /
#     325 ) -> list[pd.DataFrame | pd.Series[Any]]:
# --> 326     return [e._getitem_aggs(self) for e in exprs]
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\narwhals\_pandas_like\group_by.py:159, in AggExpr._getitem_aggs(self, group_by)
#     157 else:
#     158     select = names[0] if len(names) == 1 else list(names)
# --> 159     result = self.native_agg()(grouped[select])
#     160 if is_pandas_like_dataframe(result):
#     161     result.columns = list(self.aliases)
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\groupby.py:3381, in GroupBy.max(self, numeric_only, min_count, skipna, engine, engine_kwargs)
#    3372     return self._numba_agg_general(
#    3373         grouped_min_max,
#    3374         executor.identity_dtype_mapping,
#    (...)   3378         skipna=skipna,
#    3379     )
#    3380 else:
# -> 3381     return self._agg_general(
#    3382         numeric_only=numeric_only,
#    3383         min_count=min_count,
#    3384         skipna=skipna,
#    3385         alias="max",
#    3386         npfunc=np.max,
#    3387     )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\groupby.py:1708, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1698 @final
#    1699 def _agg_general(
#    1700     self,
#    (...)   1706     **kwargs,
#    1707 ):
# -> 1708     result = self._cython_agg_general(
#    1709         how=alias,
#    1710         alt=npfunc,
#    1711         numeric_only=numeric_only,
#    1712         min_count=min_count,
#    1713         **kwargs,
#    1714     )
#    1715     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\internals\managers.py:2274, in SingleBlockManager.grouped_reduce(self, func)
#    2272 def grouped_reduce(self, func):
#    2273     arr = self.array
# -> 2274     res = func(arr)
#    2275     index = default_index(len(res))
#    2277     mgr = type(self).from_array(res, index)
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\Hair\AppData\Local\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\arrays\categorical.py:2800, in Categorical._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2795     raise TypeError(f"{dtype} type does not support {how} operations")
#    2796 if how in ["min", "max", "rank", "idxmin", "idxmax"] and not dtype.ordered:
#    2797     # raise TypeError instead of NotImplementedError to ensure we
#    2798     #  don't go down a group-by-group path, since in the empty-groups
#    2799     #  case that would fail to raise
# -> 2800     raise TypeError(f"Cannot perform {how} with non-ordered Categorical")
#    2801 if how not in [
#    2802     "rank",
#    2803     "any",
#    (...)   2810     "idxmax",
#    2811 ]:
#    2812     if kind == "transform":
#
# TypeError: Cannot perform max with non-ordered Categorical
